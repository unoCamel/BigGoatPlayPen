# %%
# IMPORTS
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# DATA
df = pd.read_csv("datasets/insurance.csv")
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
sb.pairplot(df)

# %%
#%matplotlib notebook
#Average plots across ages

plt.scatter(df['age'], df['charges'])
plt.ylabel('Charges')
plt.show()

# %%
meanCharge = {x: df.loc[df['age'] == x].mean() for x in range(18,65)}  
plt.plot(meanCharge.keys(), meanCharge.values())
plt.ylabel('Charges')
plt.show()

# %%
ages = list(df.age.unique())
ages.sort()
means = [df[df.age==a].charges.mean() for a in ages]
plt.plot(ages,means,label='mean')
plt.scatter(df.age.values,df.charges.values,alpha=0.5,color='black',label='raw data')
plt.xlabel("age")
plt.ylabel("mean")
plt.title("age vs mean")
plt.legend()
plt.show()

# %%
from 
#Training set
all_inputs = df[['age', 'sex', 'bmi', 'children', 'smoker', 'region']].values
all_labels = df['charges'].values

all_inputs.pre
all_inputs[:5]

#training split
from sklearn.model_selection import train_test_split

(training_inputs, testing_inputs, training_classes, testing_classes) = train_test_split(all_inputs, all_labels, test_size=.25, random_state=1)

# %%
#decision tree 
from sklearn.tree import DecisionTreeClassifier

decisionTreeClassifier = DecisionTreeClassifier()
decisionTreeClassifier.fit(training_inputs, training_classes)
decisionTreeClassifier.score(testing_inputs, testing_classes)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-c748d61bc5a9> in <module>()
#       3
#       4 decisionTreeClassifier = DecisionTreeClassifier()
# ----> 5 decisionTreeClassifier.fit(training_inputs, training_classes)
#       6 decisionTreeClassifier.score(testing_inputs, testing_classes)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     788             sample_weight=sample_weight,
#     789             check_input=check_input,
# --> 790             X_idx_sorted=X_idx_sorted)
#     791         return self
#     792
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     114         random_state = check_random_state(self.random_state)
#     115         if check_input:
# ...
